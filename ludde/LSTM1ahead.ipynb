# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt


torch.manual_seed(1)

# %%
1000

8760

# %% [markdown]
# # Clean data

# %%
df = pd.read_csv('../data_NO2.csv', sep=';')
df['datetime_utc'] = pd.to_datetime(df['datetime_utc'])
df['weekday'] = df['datetime_utc'].dt.dayofweek
df['ret'] = (df['spot_price']-df['spot_price'].shift(1))/df['spot_price'].shift(1)
df = df[~df['ret'].isna()].copy()

df_weather = pd.read_csv('../data_NO2_boosted.csv')
df_weather.rename({'date': 'datetime_utc'}, axis=1, inplace=True)
df_weather['datetime_utc'] = pd.to_datetime(df_weather['datetime_utc'], utc=True)

df = pd.merge(df, df_weather[['datetime_utc', 'krs_temp_2m', 'stv_temp_2m', 'gas_price']], how='left', on='datetime_utc')
df.sort_values('datetime_utc', inplace=True)

df['date'] = df['datetime_utc'].dt.date
n_obs = df.groupby('date')['ret'].count()
odd_dates = n_obs[n_obs != 24].index
df.drop('date', axis=1, inplace=True)
# display(df[df['datetime_utc'].dt.date.isin(odd_dates)])

if len(odd_dates) > 0:
    df = df[df['datetime_utc'] < pd.to_datetime('2018-09-13 00:00:00+00:00')].copy()
    df.loc[len(df)+1, :] = [pd.to_datetime('2016-10-30 00:00:00+00:00'), 3450.5, 3027.0, 6, 32.025, -0.003888, 7.1, 8.7, 2.72]
    df.loc[len(df)+1, :] = [pd.to_datetime('2017-10-29 00:00:00+00:00'), 3584.5, 3890.0, 6, 22.325, -0.074036, 7.6, 7.9, 2.78]
df.sort_values(by='datetime_utc', inplace=True)
# df['pred_ret'] = df['ret'].shift(24)
# display(df)
# df = df.dropna(axis=0)
df.reset_index(inplace=True, drop=True)
df
# Out:
#                    datetime_utc  volume_demand  volume_production  spot_price  \
# 0     2016-01-01 00:00:00+00:00         4010.0             7694.0       16.04
# 1     2016-01-01 01:00:00+00:00         3930.0             7437.0       15.74
# 2     2016-01-01 02:00:00+00:00         3839.0             7120.0       15.57
# 3     2016-01-01 03:00:00+00:00         3833.0             7041.0       15.47
# 4     2016-01-01 04:00:00+00:00         3944.0             7246.0       15.75
# ...                         ...            ...                ...         ...
# 23659 2018-09-12 19:00:00+00:00         3848.0             6170.0       54.26
# 23660 2018-09-12 20:00:00+00:00         3706.0             5552.0       52.06
# 23661 2018-09-12 21:00:00+00:00         3534.0             5297.0       49.55
# 23662 2018-09-12 22:00:00+00:00         3399.0             4843.0       50.53
# 23663 2018-09-12 23:00:00+00:00         3287.0             4840.0       50.12
#
#        weekday       ret  krs_temp_2m  stv_temp_2m  gas_price
# 0          4.0 -0.021354          6.1          6.9       2.28
# 1          4.0 -0.018703          6.3          7.0       2.28
# 2          4.0 -0.010801          6.5          7.4       2.28
# 3          4.0 -0.006423          6.7          8.0       2.28
# 4          4.0  0.018100          6.8          7.8       2.28
# ...        ...       ...          ...          ...        ...
# 23659      2.0 -0.011297         11.3         11.7       2.94
# 23660      2.0 -0.040546         11.0         11.5       2.94
# 23661      2.0 -0.048214         10.7         10.9       2.94
# 23662      2.0  0.019778         10.3         10.7       2.94
# 23663      2.0 -0.008114         10.0         10.9       2.94
#
# [23664 rows x 9 columns]

# %%
class PriceForecastingLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(PriceForecastingLSTM, self).__init__()
        self.layer_dim = num_layers
        self.hidden_dim = hidden_size
        self.lstm_layer = nn.LSTM(input_size=input_size, 
                                  hidden_size=hidden_size, 
                                  num_layers=num_layers, 
                                  batch_first=True)
        self.fc_layer = nn.Linear(hidden_size, output_size)  # Output size = 24

    def forward(self, x):
        out, (hn, cn) = self.lstm_layer(x)
        out = self.fc_layer(out)
        return out[:,-1,:]

# %%
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(df[[
    'spot_price', 
    'volume_demand', 
    'volume_production', 
    'krs_temp_2m', 
    'stv_temp_2m', 
    'gas_price',
    'weekday']])

def create_sequences(data, input_seq_len=24, output_seq_len=1):
    X, y = [], []
    for i in range(0, len(data) - input_seq_len - output_seq_len, output_seq_len):
        X.append(data[i:i+input_seq_len])
        y.append(data[i+input_seq_len:i+input_seq_len+output_seq_len, 0])  # Only price for output
    return np.array(X), np.array(y)

X, y = create_sequences(data_normalized)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)

train_perc = 0.8
cutoff = int(len(X)*train_perc)

X_train, X_test = X[0:cutoff], X[cutoff:]
y_train, y_test = y[0:cutoff], y[cutoff:]

# Hyperparameters
input_size = 7         # Number of features (price, demand, production)
hidden_size = 64       # Number of hidden units in LSTM
num_layers = 2         # Number of LSTM layers
output_size = 1       # Forecasting 24 hours of price

model = PriceForecastingLSTM(input_size, hidden_size, num_layers, output_size)
criterion = nn.MSELoss()  # Mean Squared Error for regression
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 150
for epoch in range(num_epochs):
    model.train()
    
    # Forward pass
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    
    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if (epoch+1) % 10 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [10/150], Loss: 0.0047
# Epoch [20/150], Loss: 0.0033
# Epoch [30/150], Loss: 0.0028
# Epoch [40/150], Loss: 0.0025
# Epoch [50/150], Loss: 0.0024
# Epoch [60/150], Loss: 0.0023
# Epoch [70/150], Loss: 0.0022
# Epoch [80/150], Loss: 0.0020
# Epoch [90/150], Loss: 0.0018
# Epoch [100/150], Loss: 0.0016
# Epoch [110/150], Loss: 0.0012
# Epoch [120/150], Loss: 0.0010
# Epoch [130/150], Loss: 0.0009
# Epoch [140/150], Loss: 0.0008
# Epoch [150/150], Loss: 0.0008

# %%
model.eval()
with torch.no_grad():
    predictions = model(X_train)
    test_loss = criterion(predictions, y_train)
    print(f"Test Loss: {test_loss.item():.4f}")

pred_array = predictions.reshape(-1)
true_array = y_train.reshape(-1)



# # Inverse transform each 24-hour prediction set separately
pred_orig_scale = scaler.inverse_transform(
    np.concatenate([[pred_array], np.zeros((6, pred_array.shape[0]))], axis=0).T
)[:, 0]  # Get only the price column

true_orig_scale = scaler.inverse_transform(
    np.concatenate([[true_array], np.zeros((6, true_array.shape[0]))], axis=0).T
)[:, 0]

price_df_train = df['spot_price'].iloc[24:24+len(true_orig_scale)]

plt.figure(figsize=(16,4))

# plt.plot([i for i in range(len(true_orig_scale))], price_df_train)
plt.plot([i for i in range(len(true_orig_scale))], true_orig_scale)
plt.plot([i for i in range(len(true_orig_scale))], pred_orig_scale)
plt.grid()
plt.show()


def eval(y_true, y_pred):
    print(len(y_true))
    MSE = ((y_true-y_pred)**2).mean()
    MAE = np.abs(y_true-y_pred).mean()
    print(f"MSE: {round(MSE, 5)}")
    print(f"MAE: {round(MAE, 5)}")
    RMSE = MSE**(1/2)
    print(f"RMSE: {round(RMSE, 5)}")
eval(true_orig_scale, pred_orig_scale)
# Out:
# Test Loss: 0.0008
# 18911
# MSE: 9.88419
# MAE: 1.60098
# RMSE: 3.14391

# %%
model.eval()
with torch.no_grad():
    predictions = model(X_test)
pred_array = predictions.reshape(-1)
true_array = y_test.reshape(-1)

pred_orig_scale = scaler.inverse_transform(
    np.concatenate([[pred_array], np.zeros((6, pred_array.shape[0]))], axis=0).T
)[:, 0]

true_orig_scale = scaler.inverse_transform(
    np.concatenate([[true_array], np.zeros((6, true_array.shape[0]))], axis=0).T
)[:, 0]

eval(true_orig_scale, pred_orig_scale)
# Out:
# 4728
# MSE: 48.26193
# MAE: 5.76828
# RMSE: 6.94708

# %%
plt.figure(figsize=(16,10))

plt.plot([i for i in range(len(true_orig_scale))], true_orig_scale, label='true')
plt.plot([i for i in range(len(pred_orig_scale))], pred_orig_scale, label='pred')
plt.legend()
plt.grid()
plt.show()
