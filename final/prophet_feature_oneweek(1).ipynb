# %%
import pandas as pd
from prophet import Prophet

# %%
# Load data
data_path = "data_NO2_boosted.csv"
df = pd.read_csv(data_path)

# Convert to datetime and remove timezone
df['date'] = pd.to_datetime(df['date']).dt.tz_localize(None)

# Rename columns
df = df.rename(columns={'spot_price': 'y', 'date': 'ds'})

# Display the updated DataFrame
df.head()
# Out:
#                    ds      y  krs_temp_2m  stv_temp_2m  gas_price
# 0 2015-12-31 23:00:00  16.39          6.3          7.3       2.28
# 1 2016-01-01 00:00:00  16.04          6.1          6.9       2.28
# 2 2016-01-01 01:00:00  15.74          6.3          7.0       2.28
# 3 2016-01-01 02:00:00  15.57          6.5          7.4       2.28
# 4 2016-01-01 03:00:00  15.47          6.7          8.0       2.28

# %%
# Initialize variables for the rolling forecast
forecast_results = []  # List to store predictions
total_hours = 1000  # Example number of hours to predict; adjust as needed
forecast_horizon = 1  # Set forecast horizon to 1 hour

# Start rolling forecast
for i in range(total_hours):
    print(f"Hour {i+1} of {total_hours}")

    # Define current train set excluding the last i hours
    df_copy = df.copy()

    # Calculate the starting index to keep exactly 364 days of data (364*24 hours)
    start_index = - (365 * 24 + total_hours - i + 1)
    end_index = - (total_hours - i + 1)
    train_data = df_copy.iloc[start_index:end_index]

    # Initialize Prophet model and add extra regressors
    m = Prophet(daily_seasonality="auto", weekly_seasonality="auto", yearly_seasonality="auto")
    m.add_regressor('stv_temp_2m')
    m.add_regressor('gas_price')

    # Fit the model on the latest training data
    m.fit(train_data)

    # Create a future dataframe for the next hour
    future = m.make_future_dataframe(periods=forecast_horizon, freq='h')

    # Add regressor data for the next hour
    # Aligning the length explicitly to avoid mismatch
    future['stv_temp_2m'] = df['stv_temp_2m'].iloc[start_index:end_index+1].values
    future['gas_price'] = df['gas_price'].iloc[start_index:end_index+1].values

    # Make a one-hour prediction
    forecast = m.predict(future)

    # Store the prediction for this hour only
    forecast_1h = forecast[['ds', 'yhat']].iloc[-forecast_horizon:]
    forecast_results.append(forecast_1h)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/ld5jgw8x.json
# Hour 1 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/k1rnvg5b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4701', 'data', 'file=/tmp/tmp5h1votg2/ld5jgw8x.json', 'init=/tmp/tmp5h1votg2/k1rnvg5b.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelord8s2m8/prophet_model-20241030115146.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:51:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:51:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/f8df9ofb.json
# Hour 2 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/cbttn_dd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81488', 'data', 'file=/tmp/tmp5h1votg2/f8df9ofb.json', 'init=/tmp/tmp5h1votg2/cbttn_dd.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelmktwig4s/prophet_model-20241030115151.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:51:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:51:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/4omahzup.json
# Hour 3 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/qn2k2p3d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14266', 'data', 'file=/tmp/tmp5h1votg2/4omahzup.json', 'init=/tmp/tmp5h1votg2/qn2k2p3d.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelnxq0oh4z/prophet_model-20241030115158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:51:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:52:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/5lep1lzn.json
# Hour 4 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/4ykhj2cd.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42102', 'data', 'file=/tmp/tmp5h1votg2/5lep1lzn.json', 'init=/tmp/tmp5h1votg2/4ykhj2cd.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelovks97zq/prophet_model-20241030115204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:52:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:52:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/x1jes61j.json
# Hour 5 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/4k86ptxq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36485', 'data', 'file=/tmp/tmp5h1votg2/x1jes61j.json', 'init=/tmp/tmp5h1votg2/4k86ptxq.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelxldsy1z5/prophet_model-20241030115210.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 11:52:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 11:52:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/vw7jz6ku.json
# Hour 6 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/7ybiduuk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58106', 'data', 'file=/tmp/tmp5h1votg2/7708t12d.json', 'init=/tmp/tmp5h1votg2/ib_g4tsd.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modeluymmyfws/prophet_model-20241030132232.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:22:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/y_uw9c_x.json
# Hour 899 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/uyvytg93.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11654', 'data', 'file=/tmp/tmp5h1votg2/y_uw9c_x.json', 'init=/tmp/tmp5h1votg2/uyvytg93.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelz0ji65ex/prophet_model-20241030132238.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:22:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/kq89xakl.json
# Hour 900 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/sehcsfud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22251', 'data', 'file=/tmp/tmp5h1votg2/kq89xakl.json', 'init=/tmp/tmp5h1votg2/sehcsfud.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_model8n6vktvr/prophet_model-20241030132243.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:22:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/y9acg7ho.json
# Hour 901 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/d2zf7wlp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74094', 'data', 'file=/tmp/tmp5h1votg2/y9acg7ho.json', 'init=/tmp/tmp5h1votg2/d2zf7wlp.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_model5t1t0uvn/prophet_model-20241030132248.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:22:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Hour 902 of 1000
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/4kxr3ab9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/sz242j4q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46876', 'data', 'file=/tmp/tmp5h1votg2/4kxr3ab9.json', 'init=/tmp/tmp5h1votg2/sz242j4q.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelizjkt7x5/prophet_model-20241030132254.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:22:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/k7lkfmbv.json
# Hour 903 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/6nyk87fm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59153', 'data', 'file=/tmp/tmp5h1votg2/k7lkfmbv.json', 'init=/tmp/tmp5h1votg2/6nyk87fm.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelberti_60/prophet_model-20241030132259.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:22:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/eljr9hkg.json
# Hour 904 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/2klo4dbz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64137', 'data', 'file=/tmp/tmp5h1votg2/eljr9hkg.json', 'init=/tmp/tmp5h1votg2/2klo4dbz.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelhb21ogsc/prophet_model-20241030132307.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Hour 905 of 1000
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/p87u_wun.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/jorphbh3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8472', 'data', 'file=/tmp/tmp5h1votg2/p87u_wun.json', 'init=/tmp/tmp5h1votg2/jorphbh3.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelm1cyn0vs/prophet_model-20241030132312.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/1p7adl4q.json
# Hour 906 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/ccsz_vy9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25235', 'data', 'file=/tmp/tmp5h1votg2/1p7adl4q.json', 'init=/tmp/tmp5h1votg2/ccsz_vy9.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_model31icdicf/prophet_model-20241030132318.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/gojfswb_.json
# Hour 907 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/nslet4nj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44692', 'data', 'file=/tmp/tmp5h1votg2/gojfswb_.json', 'init=/tmp/tmp5h1votg2/nslet4nj.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modeljrfjyxzd/prophet_model-20241030132324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/8291nums.json
# Hour 908 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/me0ir34t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12285', 'data', 'file=/tmp/tmp5h1votg2/8291nums.json', 'init=/tmp/tmp5h1votg2/me0ir34t.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelsodttgna/prophet_model-20241030132329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Hour 909 of 1000
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/h8nz0bl6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/igpqahqu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=90943', 'data', 'file=/tmp/tmp5h1votg2/h8nz0bl6.json', 'init=/tmp/tmp5h1votg2/igpqahqu.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelu61c5r1f/prophet_model-20241030132336.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:23:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/c8chzg9k.json
# Hour 910 of 1000
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5h1votg2/wqbbfejx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4443', 'data', 'file=/tmp/tmp5h1votg2/c8chzg9k.json', 'init=/tmp/tmp5h1votg2/wqbbfejx.json', 'output', 'file=/tmp/tmp5h1votg2/prophet_modelx90ddo97/prophet_model-20241030132341.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:23:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing

# %%
# Combine all results into a single DataFrame
forecast_results_df = pd.concat(forecast_results, ignore_index=True)

# Display the results
print(forecast_results_df)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Rename columns in forecast_results_df to prepare for merge
forecast_results_df.columns = ['ds', 'yhat']

# Merge forecast results with actual values from df based on the timestamp 'ds'
# Selecting only the necessary columns for alignment
merged_df = pd.merge(forecast_results_df, df[['ds', 'y']], on='ds', how='inner')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(merged_df['y'], merged_df['yhat'])
print(f"Mean Absolute Error (MAE): {mae}")

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mean_squared_error(merged_df['y'], merged_df['yhat']))
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 2.8873054773617546
# Root Mean Squared Error (RMSE): 3.390567459293567

# %%
#Calculate mape
def calculate_mape(actual, predicted):
    actual, predicted = np.array(actual), np.array(predicted)
    return np.mean(np.abs((actual - predicted) / actual)) * 100

mape = calculate_mape(merged_df['y'], merged_df['yhat'])
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
# Out:
# Mean Absolute Percentage Error (MAPE): 5.156016575542657

# %% [markdown]
# Train with 364 days (date and temp*2 stv krs and gasprice):Mean Absolute Error (MAE): 4.640416961052217
# Root Mean Squared Error (RMSE): 6.426197707555815
#
# Train with 364 days (date and demand): Mean Absolute Error (MAE): 3.5591405415881954
# Root Mean Squared Error (RMSE): 5.0292826198025

# %%
x = 1000
y = 24+1
# get out rows from df_orig by indexing out
df_24_before = df.iloc[-(x+y):-y]
df_ground_truth = df.iloc[-x:]
len(forecast_results)
#print(df_24_before)
#forecast_results
# Out:
# 1000

# %%
df_24_before.iloc[-1]
df_ground_truth.iloc[-1]
# Out:
# ds             2018-09-13 02:00:00
# y                            51.81
# krs_temp_2m                   10.6
# stv_temp_2m                   11.2
# gas_price                     2.98
# Name: 23665, dtype: object

# %%
# Get the list of y hat from forecast results
y_hat_list = forecast_results_df['yhat'].tolist()

y_24_before = df_24_before['y'].tolist()

y_list = df_ground_truth['y'].tolist()

# Initialize a list to store results
results = []

# Iterate over weight combinations
for actual_weight in np.arange(0.1, 1.1, 0.1):
    forecast_weight = 1 - actual_weight

    # Calculate weighted average
    weighted_avg = actual_weight * np.array(y_24_before) + forecast_weight * np.array(y_hat_list)

    # Calculate error metrics
    mae = mean_absolute_error(np.array(y_list), weighted_avg)
    rmse = np.sqrt(mean_squared_error(np.array(y_list), weighted_avg))
    mape = np.mean(np.abs((np.array(y_list) - weighted_avg) / np.array(y_list))) * 100

    # Store the results
    results.append({
        'Actual Weight': actual_weight,
        'Forecast Weight': forecast_weight,
        'MAE': mae,
        'RMSE': rmse,
        'MAPE': mape
    })

# Convert results to DataFrame for better visualization
results_df = pd.DataFrame(results)

# Print the results
print(results_df)
# Out:
#    Actual Weight  Forecast Weight       MAE      RMSE      MAPE
# 0            0.1              0.9  3.363453  3.995251  6.650330
# 1            0.2              0.8  3.064118  3.680682  6.062321
# 2            0.3              0.7  2.781540  3.394247  5.506272
# 3            0.4              0.6  2.523418  3.143644  4.997241
# 4            0.5              0.5  2.304165  2.938058  4.562887
# 5            0.6              0.4  2.137036  2.787466  4.228538
# 6            0.7              0.3  2.011829  2.701083  3.974000
# 7            0.8              0.2  1.934774  2.685112  3.811000
# 8            0.9              0.1  1.923130  2.740786  3.777180
# 9            1.0              0.0  1.973400  2.863928  3.863921

# %%
print("24 before")
print(y_24_before[0])
print(y_24_before[-1])
print("live")
print(y_list[0])
print(y_list[-1])
# Out:
# 24 before
# 54.91
# 47.15
# live
# 54.22
# 51.81
